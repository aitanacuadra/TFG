# %%
from sqlmodel import Session, select
from main import engine, Run, RunMetadata  # reutilizas lo que ya tienes

import json
import pandas as pd

# %%
# Convertimos metadata_json (string) a un dict de Python
metas_df["metadata"] = metas_df["metadata_json"].apply(json.loads)

# Mirar el primer metadato para entender la estructura
metas_df["metadata"].iloc[16]
# Out:
# {'title': 'Datos de Estudiantes',
#  'description': 'Este dataset contiene información sobre estudiantes, incluyendo su ID, nombre, edad, grado y fecha de inscripción.',
#  'variables': [{'name': 'student_id',
#    'type': 'int64',
#    'description': 'Identificador único del estudiante.',
#    'example': 1},
#   {'name': 'name',
#    'type': 'object',
#    'description': 'Nombre completo del estudiante.',
#    'example': 'Ana Torres'},
#   {'name': 'age',
#    'type': 'int64',
#    'description': 'Edad del estudiante.',
#    'example': 19},
#   {'name': 'grade',
#    'type': 'float64',
#    'description': 'Grado académico del estudiante.',
#    'example': 8.5},
#   {'name': 'enrollment_date',
#    'type': 'object',
#    'description': 'Fecha de inscripción del estudiante.',
#    'example': '2023-09-01'}],
# ...
